# %%
import pandas as pd
excess_death_git = "https://raw.githubusercontent.com/TheEconomist/covid-19-excess-deaths-tracker/master/output-data/excess-deaths/"
weekly=pd.read_csv(excess_death_git+"all_weekly_excess_deaths.csv")
monthly=pd.read_csv(excess_death_git+"all_monthly_excess_deaths.csv")
quarterly=pd.read_csv(excess_death_git+"all_quarterly_excess_deaths.csv")
# Out:
#          country      region  region_code  start_date    end_date  days  year  \
# 0        Albania     Albania            0  2020-01-01  2020-01-31    31  2020
# 1        Albania     Albania            0  2020-02-01  2020-02-29    29  2020
# 2        Albania     Albania            0  2020-03-01  2020-03-31    31  2020
# 3        Albania     Albania            0  2020-04-01  2020-04-30    30  2020
# 4        Albania     Albania            0  2020-05-01  2020-05-31    31  2020
# ...          ...         ...          ...         ...         ...   ...   ...
# 1471  Uzbekistan  Uzbekistan            0  2021-11-01  2021-11-30    30  2021
# 1472  Uzbekistan  Uzbekistan            0  2021-12-01  2021-12-31    31  2021
# 1473  Uzbekistan  Uzbekistan            0  2022-01-01  2022-01-31    31  2022
# 1474  Uzbekistan  Uzbekistan            0  2022-02-01  2022-02-28    28  2022
# 1475  Uzbekistan  Uzbekistan            0  2022-03-01  2022-03-31    31  2022
#
# ...
